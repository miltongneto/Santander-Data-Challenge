# %%
import pandas as pd

# %%
emprestimos = pd.read_csv("../data/emprestimo/Empr_stimos_Brasil.csv")

# %%
emprestimos.head()
# Out:
#   End of Period Loan Number                       Region Country Code Country  \
# 0    06/30/2020   IBRD00111  LATIN AMERICA AND CARIBBEAN           BR  Brazil
# 1    06/30/2020   IBRD00112  LATIN AMERICA AND CARIBBEAN           BR  Brazil
# 2    06/30/2020   IBRD00250  LATIN AMERICA AND CARIBBEAN           BR  Brazil
# 3    06/30/2020   IBRD00640  LATIN AMERICA AND CARIBBEAN           BR  Brazil
# 4    06/30/2020   IBRD00650  LATIN AMERICA AND CARIBBEAN           BR  Brazil
#
#                 Borrower Guarantor Country Code Guarantor Loan Type  \
# 0  Ministério da Fazenda                     BR    Brazil       NPL
# 1  Ministério da Fazenda                     BR    Brazil       NPL
# 2  Ministério da Fazenda                     BR    Brazil       NPL
# 3  Ministério da Fazenda                     BR    Brazil       NPL
# 4  Ministério da Fazenda                     BR    Brazil       NPL
#
#        Loan Status  ...  Repaid 3rd Party  Due 3rd Party Loans Held  \
# ...

# %%
emprestimos.columns
# Out:
# Index(['End of Period', 'Loan Number', 'Region', 'Country Code', 'Country',
#        'Borrower', 'Guarantor Country Code', 'Guarantor', 'Loan Type',
#        'Loan Status', 'Interest Rate', 'Currency of Commitment', 'Project ID',
#        'Project Name', 'Original Principal Amount', 'Cancelled Amount',
#        'Undisbursed Amount', 'Disbursed Amount', 'Repaid to IBRD',
#        'Due to IBRD', 'Exchange Adjustment', 'Borrower's Obligation',
#        'Sold 3rd Party', 'Repaid 3rd Party', 'Due 3rd Party', 'Loans Held',
#        'First Repayment Date', 'Last Repayment Date', 'Agreement Signing Date',
#        'Board Approval Date', 'Effective Date (Most Recent)',
#        'Closed Date (Most Recent)', 'Last Disbursement Date'],
#       dtype='object')

# %%
emprestimos.Region.unique()
# Out:
# array(['LATIN AMERICA AND CARIBBEAN'], dtype=object)

# %%
emprestimos.Borrower.unique()
# Out:
# array(['Ministério da Fazenda', 'COMPANHIA ENERG. DE SAO PAULO',
#        'FURNAS - CENTRAIS ELETRICAS S.', 'BRASCAN LTD.',
#        'MINAS GERAIS - COMPANHIA ENERGETICA',
#        'COMPANHIA BRASILEIRA DE ENERGI', 'COMPANHIA PARANAENSE DE',
#        'COMPANHIA PAULISTA DE FORCA E', 'COMPANHIA', 'DNER',
#        'BANCO DO NORDESTE DO BRASIL S.A.', 'CENTRAIS ELETRICAS DO SUL',
#        'MINISTERIO DE EDUCACAO E CULTURA', 'PORTOBRAS',
#        'COMPANHIA DE SANEAMENTO BASICO - SAO PAU',
#        'REDE FERROVIARIA FEDERAL S. A', 'MINERACOES BRASILEIRAS REUNIDA',
#        'COMPANHIA SIDERURGICA NACIONAL-RIO DE JA',
#        'USINAS SIDERURGICAS DE MINAS',
#        'COMPANHIA SIDERURGICA PAULISTA-SAO PAULO',
#        'SUPERTENDENCIA DO DESENVOLVIME', 'BANCO DO BRASIL S.A.',
#        'BANCO CENTRAL DO BRASIL', 'SERVICOS DE ELECTRICIDADE S.A.',
#        'CO. HIDRO ELECTRICA', 'CEFED', 'DELEGADO DO MINISTERIO DE EDUC',
#        'REDE FERROVIARIA FEDERAL S.A.',
# ...
