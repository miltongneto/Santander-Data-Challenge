# %% [markdown]
# <h2> Análise Covid - Mobilidade </h2>
#
# De primeiro momento, é importante entender o cenário de pandemia no Brasil, pois é com isso que conseguimos mapear quais são os problemas que enfrentamos no momento.
# <br><br>
# Nessa primeira análise, iremos entender como o Brasil está referente a pandemia, bem como na mobilidade, do qual fizemos uma apresentação gráfica.
# <br> <br>
# *Fonte: brasil.io/dataset/covid19/caso_full/ - extraído em 02/08/2020*

# %% [markdown]
# <h3> Leitura dos Dados </h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Juliana\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
covid = pd.read_csv('../data/caso_full.csv')
covid.loc[:,'date'] = covid['date'].astype('datetime64[ns]')
covid.set_index('date', inplace=True)

# %%
# covid_state = covid[(covid['place_type']=='state')]
covid_city = covid[(covid['place_type']=='city')]

# %%
covid.columns
# Out:
# Index(['city', 'city_ibge_code', 'epidemiological_week',
#        'estimated_population_2019', 'is_last', 'is_repeated',
#        'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'order_for_place',
#        'place_type', 'state', 'new_confirmed', 'new_deaths'],
#       dtype='object')

# %% [markdown]
# <h4> Novos confirmados </h4>

# %%
ax1 = covid_city['new_confirmed'].resample('D').sum().plot(figsize=(15, 5))

# %% [markdown]
# <h4> Novas mortes </h4>

# %%
ax2 = covid_city['new_deaths'].resample('D').sum().plot(figsize=(15, 5))

# %%
print('Número de mortes: {}'.format(covid_city['new_deaths'].sum()))
print('Número de casos confirmados: {}'.format(covid_city['new_confirmed'].sum()))
# Out:
# Número de mortes: 91340
# Número de casos confirmados: 2620071

# %%
covid_city[['state','new_confirmed', 'new_deaths']].groupby('state').sum().sort_values('new_confirmed', ascending=False)
# Out:
#        new_confirmed  new_deaths
# state
# SP            542304       22997
# CE            174662        7692
# BA            166154        3463
# RJ            163642       13348
# PA            156053        5750
# MG            127106        2769
# MA            119262        2996
# DF            102342        1419
# AM            100140        3252
# PE             93373        6526
# PB             82794        1811
# ES             81886        2514
# SC             80904        1043
# GO             66899        1606
# RS             66692        1876
# PR             64259        1598
# AL             58979        1554
# SE             57684        1408
# PI             51477        1329
# RN             49151        1739
# MT             41016        1498
# RO             37634         855
# AP             36272         561
# RR             31455         501
# MS             24287         357
# TO             24278         368
# AC             19366         510

# %% [markdown]
# <h2> Análise de Mobilidade das Pessoas </h2>

# %% [markdown]
# ##### Dados podem ser acessados em:
# https://console.cloud.google.com/marketplace/product/bigquery-public-datasets/covid19_google_mobility?filter=solution-type:dataset&q=google&id=db650d71-e53e-4677-b37b-d8bdca3ec4dc&hl=pt_BR&project=metal-appliance-227513&folder=&organizationId=

# %% [markdown]
# #### Apresentação
#
# https://datastudio.google.com/s/izxdqtz3JPY
